# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data=pd.read_excel('C:\\Users\\JISHNU JAYASANKAR\\Desktop\\DSA_files\\Telco-Customer-Churn.xlsx')

# %%
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# # 1) Compare churn count with respect to gender.

# %%
#Churn Customer count
tempData=data['Churn']=='Yes'
churnData=data.loc[tempData,:]
churnData['gender'].value_counts()
# Out:
# Female    939
# Male      930
# Name: gender, dtype: int64

# %%
#Existing Customer Count
tempData=data['Churn']=='No'
churnData=data.loc[tempData,:]
churnData['gender'].value_counts()
# Out:
# Male      2625
# Female    2549
# Name: gender, dtype: int64

# %%
#Comparison Graph
plt.figure(figsize=(8,8))
sns.countplot(data=data,x='gender',hue='Churn')
plt.title('Churn count with respect to Gender',fontweight='bold',fontsize=15)
plt.yticks(np.arange(0,3000,200))
plt.grid(linestyle='--')
plt.show()

# %% [markdown]
# # 2) Findout how many female senior citizen there in the dataset

# %%
data[['gender','SeniorCitizen']].value_counts()['Female',1]
# Out:
# 568

# %% [markdown]
# # 3) Compare 'tenure' with 'Total Charges'

# %%
plt.scatter(data['tenure'],data['TotalCharges'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-9e3f6b038168> in <module>
# ----> 1 plt.scatter(data['tenure'],data['TotalCharges'])
#
# D:\Anaconda\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2888         verts=cbook.deprecation._deprecated_parameter,
#    2889         edgecolors=None, *, plotnonfinite=False, data=None, **kwargs):
# -> 2890     __ret = gca().scatter(
#    2891         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2892         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#
# D:\Anaconda\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# ...

# %% [markdown]
# We have some whitespaces in  'TotalCharges' or 'tenure'
# So, We have to find it

# %%
df=data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.loc[df['tenure']==' ']
# Out:
# Empty DataFrame
# Columns: [customerID, gender, SeniorCitizen, Partner, Dependents, tenure, PhoneService, MultipleLines, InternetService, OnlineSecurity, OnlineBackup, DeviceProtection, TechSupport, StreamingTV, StreamingMovies, Contract, PaperlessBilling, PaymentMethod, MonthlyCharges, TotalCharges, Churn]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# 'tenure' Has no whitespaces

# %%
df.loc[df['TotalCharges']==' ']
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 488   4472-LVYGI  Female              0     Yes        Yes       0
# 753   3115-CZMZD    Male              0      No        Yes       0
# 936   5709-LVOEQ  Female              0     Yes        Yes       0
# 1082  4367-NUYAO    Male              0     Yes        Yes       0
# 1340  1371-DWPAZ  Female              0     Yes        Yes       0
# 3331  7644-OMVMY    Male              0     Yes        Yes       0
# 3826  3213-VVOLG    Male              0     Yes        Yes       0
# 4380  2520-SGTTA  Female              0     Yes        Yes       0
# 5218  2923-ARZLG    Male              0     Yes        Yes       0
# 6670  4075-WKNIU  Female              0     Yes        Yes       0
# 6754  2775-SEFEE    Male              0      No        Yes       0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 488            No  No phone service             DSL                  Yes  ...
# ...

# %% [markdown]
# 'TotalCharges' Has contain 11 Whitespaces

# %%
#Take the indices having Whitespaces in 'TotalCharges'
indices=df.loc[df['TotalCharges']==' '].index

# %%
#Drop the Rows having Whitespaces in 'TotalCharges'
df.drop(indices, inplace = True)

# %%
df.loc[df['TotalCharges']==' ']
# Out:
# Empty DataFrame
# Columns: [customerID, gender, SeniorCitizen, Partner, Dependents, tenure, PhoneService, MultipleLines, InternetService, OnlineSecurity, OnlineBackup, DeviceProtection, TechSupport, StreamingTV, StreamingMovies, Contract, PaperlessBilling, PaymentMethod, MonthlyCharges, TotalCharges, Churn]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# Row Containing Whitespaces were droped

# %%
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
#Comparison Plot: tenure with Total Charges
plt.figure(figsize=(8,8))
plt.scatter(df['tenure'],df['TotalCharges'],s=10)
plt.title('Comparison Plot: tenure with Total Charges',fontweight='bold',fontsize=15)
plt.xlabel('Tenure')
plt.ylabel('TotalCharges')
# Out:
# Text(0, 0.5, 'TotalCharges')

# %% [markdown]
# # 4) Findout which contract preffered by the senior citizen.

# %%
#Picking out Senior Citizen's Data
sCitizen=data[data['SeniorCitizen']==1]
sCitizen
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 20    8779-QRDMV    Male              1      No         No       1
# 30    3841-NFECX  Female              1     Yes         No      71
# 31    4929-XIHVW    Male              1     Yes         No       2
# 34    3413-BMNZE    Male              1      No         No       1
# 50    8012-SOUDQ  Female              1      No         No      43
# ...          ...     ...            ...     ...        ...     ...
# 7023  1035-IPQPU  Female              1     Yes         No      63
# 7029  2235-DWLJU  Female              1      No         No       6
# 7031  3605-JISKB    Male              1     Yes         No      55
# 7032  6894-LFHLY    Male              1      No         No       1
# 7041  8361-LTMKD    Male              1     Yes         No       4
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 20             No  No phone service             DSL             No  ...
# ...

# %%
#Counts of varios contract preffered by the senior citizen
sCitizen['Contract'].value_counts()
# Out:
# Month-to-month    807
# One year          190
# Two year          145
# Name: Contract, dtype: int64

# %%
plt.figure(figsize=(7,7))
plt.title('Contract Preffered by the Senior Citizen',fontweight='bold',fontsize=15)
plt.pie(sCitizen['Contract'].value_counts(),labels=['Month-to-month','One year','Two year'],shadow=True,explode=(0.03, 0.03, 0.03),autopct = '%1.f%%')
plt.legend(title='Contracts')
plt.show()

# %% [markdown]
# # 5) Comment your finds on Payment Method?

# %%
data['PaymentMethod'].value_counts()
# Out:
# Electronic check             2365
# Mailed check                 1604
# Bank transfer (automatic)    1542
# Credit card (automatic)      1521
# Name: PaymentMethod, dtype: int64

# %%
plt.figure(figsize=(7,7))
plt.title('Payment Methods of All',fontweight='bold',fontsize=15)
plt.pie(data['PaymentMethod'].value_counts(),labels=['Electronic check','Mailed check','Bank transfer (automatic)','Credit card (automatic)'],autopct = '%1.f%%')
plt.legend(title='PaymentMethod')
plt.show()

# %%
sCitPayment=data[data['SeniorCitizen']==1]
sCitPayment['PaymentMethod'].value_counts()
# Out:
# Electronic check             594
# Bank transfer (automatic)    233
# Credit card (automatic)      221
# Mailed check                  94
# Name: PaymentMethod, dtype: int64

# %%
plt.figure(figsize=(7,7))
plt.title('Payment Methods of the Senior Citizen',fontweight='bold',fontsize=15)
plt.pie(sCitPayment['PaymentMethod'].value_counts(),labels=['Electronic check','Bank transfer (automatic)','Credit card (automatic)','Mailed check'],autopct = '%1.f%%')
plt.legend(title='PaymentMethod')
plt.show()

# %%
yCitPayment=data[data['SeniorCitizen']!=1]
yCitPayment['PaymentMethod'].value_counts()
# Out:
# Electronic check             1771
# Mailed check                 1510
# Bank transfer (automatic)    1309
# Credit card (automatic)      1300
# Name: PaymentMethod, dtype: int64

# %%
plt.figure(figsize=(7,7))
plt.title('Payment Methods of the Young Citizens',fontweight='bold',fontsize=15)
plt.pie(yCitPayment['PaymentMethod'].value_counts(),labels=['Electronic check','Mailed check','Bank transfer (automatic)','Credit card (automatic)'],autopct = '%1.f%%')
plt.legend(title='PaymentMethod')
plt.show()

# %% [markdown]
# * More People preffer electronic ckeck method for pay bills
# * Senior citezens like to pay bills in offline method
# * 70% Young citizens is like to pay bills through online
