# %% [markdown]
# # 1. Load the dataset into python environment

# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\JISHNU JAYASANKAR\Desktop\CaseStudy\titanic_dataset.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # 2. Make ‘PassengerId’ as the index column

# %%
df.set_index('PassengerId', inplace=True)

# %%
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S

# %% [markdown]
# # 3. Check the basic details of the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %% [markdown]
# # 4. Fill in all the missing values present in all the columns in the dataset

# %%
df.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
df.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Name         object
# Sex          object
# Age         float64
# SibSp         int64
# Parch         int64
# Ticket       object
# Fare        float64
# Cabin        object
# Embarked     object
# dtype: object

# %%
frqgraph = df.select_dtypes(include=['float64'])
frqgraph.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'Fare'}>]], dtype=object)

# %%
df['Age'] = df['Age'].fillna(df['Age'].median())
df['Embarked']=df['Embarked'].fillna(df['Embarked'].mode()[0])

# %%
df.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age           0
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      0
# dtype: int64

# %%
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 887                                      Montvila, Rev. Juozas    male  27.0
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female  28.0
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S
# ...            ...    ...               ...      ...   ...      ...
# 887              0      0            211536  13.0000   NaN        S
# 888              0      0            112053  30.0000   B42        S
# 889              1      2        W./C. 6607  23.4500   NaN        S
# 890              0      0            111369  30.0000  C148        C
# 891              0      0            370376   7.7500   NaN        Q
#
# [891 rows x 11 columns]

# %%
df.drop('Cabin', axis=1 , inplace=True)

# %%
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500        S
# 2                1      0          PC 17599  71.2833        C
# 3                0      0  STON/O2. 3101282   7.9250        S
# 4                1      0            113803  53.1000        S
# 5                0      0            373450   8.0500        S

# %% [markdown]
# # 5. Check and handle outliers in at least 3 columns in the dataset

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
df.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Embarked'],
#       dtype='object')

# %%
plt.figure(figsize=(8,8))
plt.title('Box Plot Of Fare With Outliers')
plt.boxplot(df['Fare'])
plt.show()

# %%
Q1 = np.percentile(df['Fare'],25,interpolation='midpoint')
print('Q1 =',Q1)
Q2 = np.percentile(df['Fare'],50,interpolation='midpoint')
print('Q2 =',Q2)
Q3 = np.percentile(df['Fare'],75,interpolation='midpoint')
print('Q3 =',Q3)
IQR = Q3-Q1
print('IQR =',IQR)
low_lim = Q1-1.5*IQR
print('Low Limit =',low_lim)
up_lim = Q3+1.5*IQR
print('Upper Limit =',up_lim)
df['Fare']=np.where(df['Fare']>up_lim,up_lim,np.where(df['Fare']<low_lim,low_lim,df['Fare']))
# Out:
# Q1 = 7.9104
# Q2 = 14.4542
# Q3 = 31.0
# IQR = 23.0896
# Low Limit = -26.724
# Upper Limit = 65.6344

# %%
plt.figure(figsize=(8,8))
plt.title('Box Plot Of Fare Without Outliers')
plt.boxplot(df['Fare'])
plt.show()

# %%
plt.figure(figsize=(8,8))
plt.title('Box Plot Of Age With Outliers')
plt.boxplot(df['Age'])
plt.show()

# %%
Q1 = np.percentile(df['Age'],25,interpolation='midpoint')
print('Q1 =',Q1)
Q2 = np.percentile(df['Age'],50,interpolation='midpoint')
print('Q2 =',Q2)
Q3 = np.percentile(df['Age'],75,interpolation='midpoint')
print('Q3 =',Q3)
IQR = Q3-Q1
print('IQR =',IQR)
low_lim = Q1-1.5*IQR
print('Low Limit =',low_lim)
up_lim = Q3+1.5*IQR
print('Upper Limit =',up_lim)
df['Age']=np.where(df['Age']>up_lim,up_lim,np.where(df['Age']<low_lim,low_lim,df['Age']))
# Out:
# Q1 = 22.0
# Q2 = 28.0
# Q3 = 35.0
# IQR = 13.0
# Low Limit = 2.5
# Upper Limit = 54.5

# %%
plt.figure(figsize=(8,8))
plt.title('Box Plot Of Age Without Outliers')
plt.boxplot(df['Age'])
plt.show()

# %%
plt.figure(figsize=(8,8))
plt.title('Box Plot Of SibSp With Outliers')
plt.boxplot(df['SibSp'])
plt.show()

# %%
Q1 = np.percentile(df['SibSp'],25,interpolation='midpoint')
print('Q1 =',Q1)
Q2 = np.percentile(df['SibSp'],50,interpolation='midpoint')
print('Q2 =',Q2)
Q3 = np.percentile(df['SibSp'],75,interpolation='midpoint')
print('Q3 =',Q3)
IQR = Q3-Q1
print('IQR =',IQR)
low_lim = Q1-1.5*IQR
print('Low Limit =',low_lim)
up_lim = Q3+1.5*IQR
print('Upper Limit =',up_lim)
ind1 = df['SibSp']>up_lim
indices = df.loc[ind1].index
df.drop(indices, inplace=True)
# Out:
# Q1 = 0.0
# Q2 = 0.0
# Q3 = 1.0
# IQR = 1.0
# Low Limit = -1.5
# Upper Limit = 2.5

# %%
plt.figure(figsize=(8,8))
plt.title('Box Plot Of SibSp Without Outliers')
plt.boxplot(df['SibSp'])
plt.show()

# %% [markdown]
# # 6. Do min max scaling on the feature set (Take ‘Survived’ as target)

# %%
df = df.drop('Ticket',axis=1)

# %%
data = pd.get_dummies(df)
data
# Out:
#              Survived  Pclass   Age  SibSp  Parch     Fare  Sex_female  \
# PassengerId
# 1                   0       3  22.0      1      0   7.2500           0
# 2                   1       1  38.0      1      0  65.6344           1
# 3                   1       3  26.0      0      0   7.9250           1
# 4                   1       1  35.0      1      0  53.1000           1
# 5                   0       3  35.0      0      0   8.0500           0
# ...               ...     ...   ...    ...    ...      ...         ...
# 887                 0       2  27.0      0      0  13.0000           0
# 888                 1       1  19.0      0      0  30.0000           1
# 889                 0       3  28.0      1      2  23.4500           1
# 890                 1       1  26.0      0      0  30.0000           0
# 891                 0       3  32.0      0      0   7.7500           0
#
#              Sex_male  Embarked_C  Embarked_Q  Embarked_S
# PassengerId
# 1                   1           0           0           1
# 2                   0           1           0           0
# 3                   0           0           0           1
# 4                   0           0           0           1
# 5                   1           0           0           1
# ...               ...         ...         ...         ...
# 887                 1           0           0           1
# 888                 0           0           0           1
# 889                 0           0           0           1
# 890                 1           1           0           0
# 891                 1           0           1           0
#
# [845 rows x 11 columns]

# %%
y = data['Survived']
X = data.drop('Survived', axis=1)

# %%
# train and test split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X, y, random_state=42, test_size=0.2)
# Linear model
from sklearn import linear_model
lr = linear_model.LinearRegression()
model = lr.fit(X_train,y_train)
predictions = model.predict(X_test)
# MSE and R Squared
from sklearn.metrics import mean_squared_error, r2_score
print("MSE is: ", mean_squared_error(y_test, predictions))
print("R Squared is: ", r2_score(y_test, predictions))
# Out:
# MSE is:  0.11971495322495657
# R Squared is:  0.4596746556482326

# %%
X.describe()
# Out:
#            Pclass         Age       SibSp       Parch        Fare  Sex_female  \
# count  845.000000  845.000000  845.000000  845.000000  845.000000  845.000000
# mean     2.279290   29.840828    0.313609    0.317160   23.251982    0.346746
# std      0.840396   11.636290    0.530909    0.765829   20.385279    0.476216
# min      1.000000    2.500000    0.000000    0.000000    0.000000    0.000000
# 25%      1.000000   23.000000    0.000000    0.000000    7.895800    0.000000
# 50%      3.000000   28.000000    0.000000    0.000000   13.000000    0.000000
# 75%      3.000000   36.000000    1.000000    0.000000   30.000000    1.000000
# max      3.000000   54.500000    2.000000    6.000000   65.634400    1.000000
#
#          Sex_male  Embarked_C  Embarked_Q  Embarked_S
# count  845.000000  845.000000  845.000000  845.000000
# mean     0.653254    0.198817    0.086391    0.714793
# std      0.476216    0.399346    0.281106    0.451780
# min      0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000
# 50%      1.000000    0.000000    0.000000    1.000000
# 75%      1.000000    0.000000    0.000000    1.000000
# max      1.000000    1.000000    1.000000    1.000000

# %%
min_max = preprocessing.MinMaxScaler(feature_range=(0,1))
X = min_max.fit_transform(X)

# %%
X = pd.DataFrame(X)

# %%
X.describe()
# Out:
#                 0           1           2           3           4           5  \
# count  845.000000  845.000000  845.000000  845.000000  845.000000  845.000000
# mean     0.639645    0.525785    0.156805    0.052860    0.354265    0.346746
# std      0.420198    0.223775    0.265454    0.127638    0.310588    0.476216
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.394231    0.000000    0.000000    0.120300    0.000000
# 50%      1.000000    0.490385    0.000000    0.000000    0.198067    0.000000
# 75%      1.000000    0.644231    0.500000    0.000000    0.457077    1.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#                 6           7           8           9
# count  845.000000  845.000000  845.000000  845.000000
# mean     0.653254    0.198817    0.086391    0.714793
# std      0.476216    0.399346    0.281106    0.451780
# min      0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000
# 50%      1.000000    0.000000    0.000000    1.000000
# 75%      1.000000    0.000000    0.000000    1.000000
# max      1.000000    1.000000    1.000000    1.000000

# %%
# Checking the sacling is did well
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X, y, random_state=42, test_size=0.2)
from sklearn import linear_model
lr = linear_model.LinearRegression()
model = lr.fit(X_train,y_train)
predictions = model.predict(X_test)
from sklearn.metrics import mean_squared_error, r2_score
print("MSE is: ", mean_squared_error(y_test, predictions))
print("R Squared is: ", r2_score(y_test, predictions))
# Out:
# MSE is:  0.11971495322495655
# R Squared is:  0.45967465564823273

# %% [markdown]
# there is only a tiny change in R2 value , so the Scaling is fine
